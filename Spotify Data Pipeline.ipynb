# %%
# !pip install spotipy

# %% [markdown]
# # SPOTIPY documentation https://spotipy.readthedocs.io/en/2.22.1/

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager= SpotifyClientCredentials(client_id=<input>,client_secret=<input>)

# %%
# creating a Spotify object
sp= spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# ***
#
# ***
# We are choosing **Top Songs Global**
# URL : https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF
# ***
#
# ***

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"

# %% [markdown]
# Here from the link we only need the ID for the playlist which is : **37i9dQZEVXbNG2KDcFcKOF**

# %%
playlist_link.split('/')
# Out:
# ['https:', '', 'open.spotify.com', 'playlist', '37i9dQZEVXbNG2KDcFcKOF']

# %%
playlist_URI=playlist_link.split('/')[-1]
playlist_URI
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
spotify_data=sp.playlist_tracks(playlist_URI)
spotify_data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-07-14T15:32:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7iK8PXO48WeuP03g8YR51W'},
#        'href': 'https://api.spotify.com/v1/artists/7iK8PXO48WeuP03g8YR51W',
#        'id': '7iK8PXO48WeuP03g8YR51W',
#        'name': 'Myke Towers',
#        'type': 'artist',
#        'uri': 'spotify:artist:7iK8PXO48WeuP03g8YR51W'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
# ...

# %%
len(spotify_data['items'])
# Out:
# 50

# %%
spotify_data['items'][0]['track']['album']['id']
# Out:
# '3puAvurwvtvi1rodndIPW8'

# %%
spotify_data['items'][0]['track']['album']['name']
# Out:
# 'LA VIDA ES UNA'

# %%
spotify_data['items'][0]['track']['album']['release_date']
# Out:
# '2023-03-23'

# %%
spotify_data['items'][0]['track']['album']['total_tracks']
# Out:
# 23

# %%
spotify_data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/3puAvurwvtvi1rodndIPW8'

# %%
album_list=[]
for row in spotify_data['items']:
    album_id=row['track']['album']['id']
    album_name=row['track']['album']['name']
    album_release_date=row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_url=row['track']['album']['external_urls']['spotify']
    
    album_element={'album_id':album_id ,'album_name':album_name , 'album_release_date':album_release_date ,
                   'album_total_tracks':album_total_tracks,'album_url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '3puAvurwvtvi1rodndIPW8',
#   'album_name': 'LA VIDA ES UNA',
#   'album_release_date': '2023-03-23',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/3puAvurwvtvi1rodndIPW8'},
#  {'album_id': '5kqfR7EuGbyp8x27Pr1kY9',
#   'album_name': 'vampire',
#   'album_release_date': '2023-06-30',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5kqfR7EuGbyp8x27Pr1kY9'},
#  {'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'album_name': 'Lover',
#   'album_release_date': '2019-08-23',
#   'album_total_tracks': 18,
#   'album_url': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#  {'album_id': '5AEDGbliTTfjOB8TSm1sxt',
#   'album_name': "Speak Now (Taylor's Version)",
#   'album_release_date': '2023-07-07',
#   'album_total_tracks': 22,
#   'album_url': 'https://open.spotify.com/album/5AEDGbliTTfjOB8TSm1sxt'},
#  {'album_id': '5aDEezKnOqyQo0qvTFhpkM',
#   'album_name': 'DESVELADO',
# ...

# %%
spotify_data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7iK8PXO48WeuP03g8YR51W'},
#   'href': 'https://api.spotify.com/v1/artists/7iK8PXO48WeuP03g8YR51W',
#   'id': '7iK8PXO48WeuP03g8YR51W',
#   'name': 'Myke Towers',
#   'type': 'artist',
#   'uri': 'spotify:artist:7iK8PXO48WeuP03g8YR51W'}]

# %%
spotify_data['items'][4]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XeEobZplHxzM9QzFQWLiR'},
#   'href': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR',
#   'id': '0XeEobZplHxzM9QzFQWLiR',
#   'name': 'Eslabon Armado',
#   'type': 'artist',
#   'uri': 'spotify:artist:0XeEobZplHxzM9QzFQWLiR'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#   'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#   'id': '12GqGscKJx3aE4t07u7eVZ',
#   'name': 'Peso Pluma',
#   'type': 'artist',
#   'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'}]

# %%
artist_list=[]
for row in spotify_data['items']:
    for key,value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict={'artist_id':artist['id'] ,'artist_name':artist['name'],
                 'external_url':artist['href'],'artist_type':artist['type']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '7iK8PXO48WeuP03g8YR51W',
#   'artist_name': 'Myke Towers',
#   'external_url': 'https://api.spotify.com/v1/artists/7iK8PXO48WeuP03g8YR51W',
#   'artist_type': 'artist'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'external_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#   'artist_type': 'artist'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#   'artist_type': 'artist'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#   'artist_type': 'artist'},
#  {'artist_id': '0XeEobZplHxzM9QzFQWLiR',
#   'artist_name': 'Eslabon Armado',
#   'external_url': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR',
#   'artist_type': 'artist'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
# ...

# %%
spotify_data['items'][0]['track']
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7iK8PXO48WeuP03g8YR51W'},
#     'href': 'https://api.spotify.com/v1/artists/7iK8PXO48WeuP03g8YR51W',
#     'id': '7iK8PXO48WeuP03g8YR51W',
#     'name': 'Myke Towers',
#     'type': 'artist',
#     'uri': 'spotify:artist:7iK8PXO48WeuP03g8YR51W'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
# ...

# %%
song_list = []
for row in spotify_data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df=pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                    album_name album_release_date  \
# 0  3puAvurwvtvi1rodndIPW8                LA VIDA ES UNA         2023-03-23
# 1  5kqfR7EuGbyp8x27Pr1kY9                       vampire         2023-06-30
# 2  1NAmidJlEaVgA3MpcPFYGq                         Lover         2019-08-23
# 3  5AEDGbliTTfjOB8TSm1sxt  Speak Now (Taylor's Version)         2023-07-07
# 4  5aDEezKnOqyQo0qvTFhpkM                     DESVELADO         2023-04-28
#
#    album_total_tracks                                          album_url
# 0                  23  https://open.spotify.com/album/3puAvurwvtvi1ro...
# 1                   1  https://open.spotify.com/album/5kqfR7EuGbyp8x2...
# 2                  18  https://open.spotify.com/album/1NAmidJlEaVgA3M...
# 3                  22  https://open.spotify.com/album/5AEDGbliTTfjOB8...
# 4                  16  https://open.spotify.com/album/5aDEezKnOqyQo0q...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            50 non-null     object
#  1   album_name          50 non-null     object
#  2   album_release_date  50 non-null     object
#  3   album_total_tracks  50 non-null     int64
#  4   album_url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
# Dropping duplicates
album_df = album_df.drop_duplicates(subset='album_id')

# %%
artist_df=pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  7iK8PXO48WeuP03g8YR51W     Myke Towers
# 1  1McMsnEElThX1knmY4oliG  Olivia Rodrigo
# 2  06HL4z0CvFAxyc27GXpf02    Taylor Swift
# 3  06HL4z0CvFAxyc27GXpf02    Taylor Swift
# 4  0XeEobZplHxzM9QzFQWLiR  Eslabon Armado
#
#                                         external_url artist_type
# 0  https://api.spotify.com/v1/artists/7iK8PXO48We...      artist
# 1  https://api.spotify.com/v1/artists/1McMsnEElTh...      artist
# 2  https://api.spotify.com/v1/artists/06HL4z0CvFA...      artist
# 3  https://api.spotify.com/v1/artists/06HL4z0CvFA...      artist
# 4  https://api.spotify.com/v1/artists/0XeEobZplHx...      artist

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     77 non-null     object
#  1   artist_name   77 non-null     object
#  2   external_url  77 non-null     object
#  3   artist_type   77 non-null     object
# dtypes: object(4)
# memory usage: 2.5+ KB

# %%
artist_df=artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  7iK8PXO48WeuP03g8YR51W     Myke Towers
# 1  1McMsnEElThX1knmY4oliG  Olivia Rodrigo
# 2  06HL4z0CvFAxyc27GXpf02    Taylor Swift
# 4  0XeEobZplHxzM9QzFQWLiR  Eslabon Armado
# 5  12GqGscKJx3aE4t07u7eVZ      Peso Pluma
#
#                                         external_url artist_type
# 0  https://api.spotify.com/v1/artists/7iK8PXO48We...      artist
# 1  https://api.spotify.com/v1/artists/1McMsnEElTh...      artist
# 2  https://api.spotify.com/v1/artists/06HL4z0CvFA...      artist
# 4  https://api.spotify.com/v1/artists/0XeEobZplHx...      artist
# 5  https://api.spotify.com/v1/artists/12GqGscKJx3...      artist

# %%
song_df=pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                                          song_name  \
# 0  7ABLbnD53cQK00mhcaOUVG                                               LALA
# 1  3k79jB4aGmMDUQzEwa46Rz                                            vampire
# 2  1BxfuPKGuaTgP7aM0Bbdwr                                       Cruel Summer
# 3  5kHMfzgLZP95O9NBy0ku4v  I Can See You (Taylor’s Version) (From The Vault)
# 4  3qQbCzHBycnDpGskqOWY0E                                    Ella Baila Sola
#
#    duration_ms                                                url  popularity  \
# 0       197920  https://open.spotify.com/track/7ABLbnD53cQK00m...          97
# 1       219724  https://open.spotify.com/track/3k79jB4aGmMDUQz...          98
# 2       178426  https://open.spotify.com/track/1BxfuPKGuaTgP7a...          99
# 3       273186  https://open.spotify.com/track/5kHMfzgLZP95O9N...          93
# 4       165671  https://open.spotify.com/track/3qQbCzHBycnDpGs...          93
#
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     object
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.2+ KB

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            35 non-null     object
#  1   album_name          35 non-null     object
#  2   album_release_date  35 non-null     object
#  3   album_total_tracks  35 non-null     int64
#  4   album_url           35 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.6+ KB

# %%
album_df['album_release_date']=pd.to_datetime(album_df['album_release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            35 non-null     object
#  1   album_name          35 non-null     object
#  2   album_release_date  35 non-null     datetime64[ns]
#  3   album_total_tracks  35 non-null     int64
#  4   album_url           35 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.6+ KB

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
